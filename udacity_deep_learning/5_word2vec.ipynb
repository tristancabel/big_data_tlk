# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'term', 'a', 'of', 'originated', 'as', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  #tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.193729
# Nearest to often: countable, belief, owl, surely, npr, nitride, stretches, overwritten,
# Nearest to time: unnoticed, hao, spacey, ret, php, adhesives, walnut, citation,
# Nearest to if: eagle, housework, discharges, mailboxes, satisfaction, ravages, claudian, vous,
# Nearest to and: paran, mcgwire, dope, maneuvered, ferromagnetism, fullwidth, crowned, damned,
# Nearest to a: knudsen, cimmerian, financiers, characters, device, gaspar, chapman, slays,
# Nearest to american: headlights, hundredth, genetic, cha, longue, abdurrahman, carbons, colt,
# Nearest to used: outbreaks, fascist, vitae, arrangements, seventeen, roundly, catabolism, consequence,
# Nearest to one: interactive, cursed, heme, reminiscences, runnymede, godfather, athenian, tagline,
# Nearest to these: exponent, destry, vers, thickly, rape, concertos, pergamum, encyclopedia,
# Nearest to many: musician, conspiring, dwindled, lynn, que, pray, sensations, grands,
# Nearest to united: glastonbury, halting, freeway, enhance, constitutions, cabell, breatharian, antiquarian,
# Nearest to of: rushes, withdrawal, elaborating, liffey, ponce, enrolled, cer, condoned,
# Nearest to by: opal, softened, vietnam, communions, millard, oup, deterministic, klan,
# Nearest to zero: babi, moderate, foreshadowed, baskerville, chunk, encompassing, altogether, deists,
# Nearest to will: harsher, bearings, tighter, scars, obvious, hippo, mile, bamako,
# Nearest to system: hon, fyodorovna, ment, sca, yorker, lose, yarmouth, maarten,
# Average loss at step 2000: 4.360318
# Average loss at step 4000: 3.862401
# Average loss at step 6000: 3.784684
# Average loss at step 8000: 3.689190
# Average loss at step 10000: 3.613517
# Nearest to often: also, manufactures, rhodesian, more, it, countable, not, sindhu,
# Nearest to time: capillary, despot, photovoltaic, guernica, laptop, jia, codeword, gazing,
# Nearest to if: federal, eagle, mailboxes, discharges, argyle, ravages, ystok, sacred,
# Nearest to and: or, american, who, in, d, he, goto, dolly,
# Nearest to a: the, hoffer, unfortunately, his, kurtosis, this, socratic, cubist,
# Nearest to american: abuse, and, betrayal, colt, abdurrahman, heresy, headlights, growing,
# Nearest to used: brythonic, arrangements, trey, fascist, caen, believe, found, gasolines,
# Nearest to one: two, three, six, seven, four, five, freedmen, luminous,
# Nearest to these: qui, some, replacement, judaic, vengeful, appeared, hbf, proportions,
# Nearest to many: their, some, zog, pretense, zawahiri, maligned, other, began,
# Nearest to united: glastonbury, halting, indicator, bribes, unacceptably, in, buckwheat, pilots,
# Nearest to of: in, same, for, excised, last, on, firmware, weierstrass,
# Nearest to by: was, with, been, corfu, on, at, be, prompting,
# Nearest to zero: six, eight, nine, seven, five, three, four, two,
# Nearest to will: can, shoal, could, bearings, noxious, milder, harsher, outposts,
# Nearest to system: hon, fyodorovna, philippines, gilgal, scaffolding, sca, yorker, wreath,
# Average loss at step 12000: 3.603124
# Average loss at step 14000: 3.569421
# Average loss at step 16000: 3.408958
# Average loss at step 18000: 3.457897
# Average loss at step 20000: 3.541530
# Nearest to often: also, who, manufactures, sometimes, usually, it, countable, commonly,
# Nearest to time: year, laptop, capillary, jia, photovoltaic, despot, codeword, cymbals,
# Nearest to if: though, when, butane, mailboxes, does, can, federal, eagle,
# Nearest to and: or, but, in, vital, from, which, at, for,
# Nearest to a: hoffer, the, another, this, hoist, any, khair, cays,
# Nearest to american: british, english, colt, fusing, abuse, growing, french, joss,
# Nearest to used: brythonic, found, trey, arrangements, caen, considered, sherbrooke, known,
# Nearest to one: two, four, six, seven, three, five, eight, temperament,
# Nearest to these: some, many, other, such, their, all, gentleman, qui,
# Nearest to many: some, other, these, several, all, their, questions, tano,
# Nearest to united: glastonbury, indicator, unacceptably, halting, buckwheat, derision, greeks, hudson,
# Nearest to of: same, nil, and, for, weierstrass, voronin, norad, nne,
# Nearest to by: be, in, cruiser, were, ponies, was, after, with,
# Nearest to zero: five, six, three, seven, eight, four, nine, two,
# Nearest to will: can, may, would, could, should, must, might, cannot,
# Nearest to system: hon, fyodorovna, scaffolding, manama, philippines, gilgal, collar, yarmouth,
# Average loss at step 22000: 3.501866
# Average loss at step 24000: 3.490460
# Average loss at step 26000: 3.480666
# Average loss at step 28000: 3.480257
# Average loss at step 30000: 3.501500
# Nearest to often: sometimes, also, usually, commonly, still, generally, now, manufactures,
# Nearest to time: year, photovoltaic, laptop, capillary, benchmarking, neglected, gazing, cymbals,
# Nearest to if: when, though, so, but, because, butane, could, can,
# Nearest to and: or, but, in, who, however, rossini, tran, comptroller,
# Nearest to a: the, socratic, hoist, no, etzel, any, their, gustloff,
# Nearest to american: british, english, canadian, australian, fusing, french, colt, gting,
# Nearest to used: brythonic, found, known, given, sherbrooke, accepted, described, responsible,
# Nearest to one: two, seven, six, three, four, eight, five, nine,
# Nearest to these: some, many, they, such, other, their, all, several,
# Nearest to many: some, several, these, other, all, tano, various, their,
# Nearest to united: glastonbury, indicator, unacceptably, derision, buckwheat, eurofighter, city, hudson,
# Nearest to of: in, for, same, from, nil, weierstrass, and, firmware,
# Nearest to by: with, inhalants, ponies, from, extensive, were, prompting, patmos,
# Nearest to zero: five, three, seven, four, eight, six, nine, two,
# Nearest to will: would, can, may, could, should, must, might, cannot,
# Nearest to system: hon, fyodorovna, scaffolding, manama, climate, poorest, systems, philippines,
# Average loss at step 32000: 3.504098
# Average loss at step 34000: 3.497294
# Average loss at step 36000: 3.454665
# Average loss at step 38000: 3.304463
# Average loss at step 40000: 3.432487
# Nearest to often: usually, also, sometimes, commonly, generally, who, still, typically,
# Nearest to time: year, photovoltaic, gazing, laptop, fabricate, amadeus, kaufmann, picasso,
# Nearest to if: when, though, so, where, is, for, lagoons, can,
# Nearest to and: or, but, molybdenum, gascony, in, slew, of, beet,
# Nearest to a: another, the, or, wight, hoffer, kurtosis, unguarded, any,
# Nearest to american: british, australian, canadian, english, fullwidth, colt, french, european,
# Nearest to used: found, brythonic, known, given, described, referred, considered, seen,
# Nearest to one: two, four, seven, six, eight, five, three, nine,
# Nearest to these: some, many, several, such, various, they, those, both,
# Nearest to many: some, several, these, various, most, their, all, such,
# Nearest to united: glastonbury, derision, buckwheat, unacceptably, indicator, eurofighter, greeks, legislature,
# Nearest to of: in, from, underhill, for, blanking, and, kames, cursing,
# Nearest to by: patmos, dw, be, was, inhalants, lifts, from, corfu,
# Nearest to zero: seven, nine, five, eight, three, six, four, u,
# Nearest to will: would, can, may, could, must, should, might, cannot,
# Nearest to system: systems, hon, andorra, fyodorovna, manama, gilgal, attractive, fresco,
# Average loss at step 42000: 3.428707
# Average loss at step 44000: 3.455796
# Average loss at step 46000: 3.448597
# Average loss at step 48000: 3.353465
# Average loss at step 50000: 3.380485
# Nearest to often: usually, sometimes, commonly, generally, typically, also, widely, still,
# Nearest to time: year, purpose, dworkin, photovoltaic, kaufmann, day, analytic, period,
# Nearest to if: when, though, where, so, although, before, but, bordering,
# Nearest to and: or, but, while, of, ascendant, silas, in, racks,
# Nearest to a: the, another, any, unguarded, kendo, patched, thyroxine, etzel,
# Nearest to american: british, european, australian, english, canadian, colt, french, fullwidth,
# Nearest to used: known, described, found, referred, brythonic, written, seen, given,
# Nearest to one: two, eight, seven, six, four, three, five, nine,
# Nearest to these: some, many, such, several, both, various, those, they,
# Nearest to many: some, several, these, various, both, most, other, scholars,
# Nearest to united: glastonbury, eurofighter, unacceptably, derision, legislature, greeks, buckwheat, indicator,
# Nearest to of: including, in, and, same, nil, during, kames, rangoon,
# Nearest to by: through, was, extensive, after, cruiser, with, millard, under,
# Nearest to zero: five, seven, four, six, three, eight, nine, two,
# Nearest to will: would, can, could, may, should, must, might, cannot,
# Nearest to system: systems, manama, climate, fyodorovna, hon, gilgal, andorra, untenable,
# Average loss at step 52000: 3.434991
# Average loss at step 54000: 3.428223
# Average loss at step 56000: 3.436169
# Average loss at step 58000: 3.396711
# Average loss at step 60000: 3.397554
# Nearest to often: usually, sometimes, commonly, typically, generally, widely, frequently, also,
# Nearest to time: year, purpose, dworkin, analytic, kaufmann, reinvent, day, period,
# Nearest to if: when, where, though, so, because, before, although, since,
# Nearest to and: or, but, than, while, including, jensen, pisano, cfo,
# Nearest to a: the, another, any, kendo, tune, aneurin, warwickshire, nonsignatory,
# Nearest to american: european, australian, british, canadian, english, colt, fullwidth, indian,
# Nearest to used: described, known, referred, brythonic, found, written, available, considered,
# Nearest to one: two, six, eight, four, five, seven, three, nine,
# Nearest to these: many, some, those, such, several, both, they, various,
# Nearest to many: some, several, various, these, most, both, such, other,
# Nearest to united: eurofighter, legislature, glastonbury, unacceptably, greeks, derision, buckwheat, konstantin,
# Nearest to of: in, for, like, same, underhill, or, callisto, including,
# Nearest to by: through, acadians, flavoured, extensive, with, inhalants, millard, before,
# Nearest to zero: five, four, six, seven, eight, three, nine, kg,
# Nearest to will: would, can, may, could, should, must, might, cannot,
# Nearest to system: systems, climate, product, gilgal, untenable, lose, network, fyodorovna,
# Average loss at step 62000: 3.241065
# Average loss at step 64000: 3.255738
# Average loss at step 66000: 3.398555
# Average loss at step 68000: 3.392735
# Average loss at step 70000: 3.359803
# Nearest to often: sometimes, usually, commonly, generally, frequently, typically, now, also,
# Nearest to time: year, reinvent, analytic, vga, neglected, decade, purpose, diaz,
# Nearest to if: when, though, where, before, so, although, while, because,
# Nearest to and: or, while, but, however, of, gascony, outbound, cloned,
# Nearest to a: the, another, any, kendo, this, talkative, each, misconceptions,
# Nearest to american: european, canadian, british, australian, english, colt, indian, fullwidth,
# Nearest to used: known, described, available, referred, found, written, seen, responsible,
# Nearest to one: two, seven, six, four, eight, three, five, nine,
# Nearest to these: many, such, some, those, they, several, various, different,
# Nearest to many: some, several, various, these, most, all, both, such,
# Nearest to united: legislature, derision, nation, konstantin, eurofighter, buckwheat, greeks, indicator,
# Nearest to of: including, and, include, for, in, underhill, thrash, like,
# Nearest to by: through, acadians, millard, in, inhalants, comerica, from, prompting,
# Nearest to zero: five, six, four, eight, seven, three, nine, two,
# Nearest to will: would, could, may, can, should, must, might, cannot,
# Nearest to system: systems, network, fresco, intermediates, unearthed, asexual, lose, yarmouth,
# Average loss at step 72000: 3.376046
# Average loss at step 74000: 3.347065
# Average loss at step 76000: 3.319880
# Average loss at step 78000: 3.352087
# Average loss at step 80000: 3.374381
# Nearest to often: sometimes, usually, commonly, generally, typically, frequently, widely, now,
# Nearest to time: year, reinvent, benchmarking, photovoltaic, category, correction, lasted, reformulated,
# Nearest to if: when, though, where, so, because, although, since, before,
# Nearest to and: or, but, while, including, invalidating, aum, szl, representational,
# Nearest to a: another, the, misconceptions, gogh, gustloff, hoffer, falco, kendo,
# Nearest to american: european, british, australian, colt, canadian, french, joss, italian,
# Nearest to used: known, described, written, available, referred, found, seen, responsible,
# Nearest to one: two, six, seven, three, four, eight, five, nine,
# Nearest to these: several, many, those, some, such, various, both, they,
# Nearest to many: some, several, various, these, most, both, all, few,
# Nearest to united: nation, derision, legislature, same, eurofighter, konstantin, indicator, buckwheat,
# Nearest to of: in, including, bumpy, pringle, pyroxene, humber, existentialism, jacobite,
# Nearest to by: through, hun, from, asoka, robins, inhalants, reestablishment, millard,
# Nearest to zero: seven, five, six, four, three, eight, nine, million,
# Nearest to will: would, can, could, may, should, must, might, cannot,
# Nearest to system: systems, manama, storage, apologists, hon, climate, quack, nobi,
# Average loss at step 82000: 3.409895
# Average loss at step 84000: 3.408591
# Average loss at step 86000: 3.387227
# Average loss at step 88000: 3.352863
# Average loss at step 90000: 3.363742
# Nearest to often: sometimes, usually, commonly, generally, typically, frequently, actually, also,
# Nearest to time: year, reinvent, before, category, period, lasted, diaz, headset,
# Nearest to if: when, though, where, so, before, since, although, phenomenology,
# Nearest to and: or, but, while, in, including, therus, of, cmos,
# Nearest to a: another, any, the, southend, unguarded, kendo, etzel, falco,
# Nearest to american: british, european, australian, italian, canadian, french, indian, brazilian,
# Nearest to used: known, referred, described, written, available, found, designed, seen,
# Nearest to one: two, four, seven, six, three, eight, five, affricates,
# Nearest to these: several, many, some, such, are, various, those, both,
# Nearest to many: some, several, various, these, all, most, both, few,
# Nearest to united: derision, nation, same, legislature, konstantin, eurofighter, indicator, greeks,
# Nearest to of: for, in, including, and, underhill, rejoin, governing, ultimate,
# Nearest to by: through, inhalants, with, endorses, without, from, under, reestablishment,
# Nearest to zero: five, seven, eight, six, three, four, nine, two,
# Nearest to will: would, could, can, should, must, may, might, cannot,
# Nearest to system: systems, product, hon, program, unearthed, phosphors, nobi, quack,
# Average loss at step 92000: 3.397051
# Average loss at step 94000: 3.254407
# Average loss at step 96000: 3.355323
# Average loss at step 98000: 3.242979
# Average loss at step 100000: 3.355676
# Nearest to often: sometimes, usually, generally, commonly, frequently, typically, still, actually,
# Nearest to time: year, lasted, reinvent, before, doubled, kind, fabricate, category,
# Nearest to if: when, though, where, before, because, although, so, phenomenology,
# Nearest to and: but, or, while, however, although, who, like, when,
# Nearest to a: another, the, any, unguarded, kendo, wight, misconceptions, concentrated,
# Nearest to american: british, australian, canadian, italian, french, atlantans, colt, cheech,
# Nearest to used: referred, described, available, known, written, found, designed, seen,
# Nearest to one: two, four, five, seven, six, three, eight, millimeters,
# Nearest to these: several, many, some, various, those, such, all, certain,
# Nearest to many: several, some, various, these, all, numerous, few, certain,
# Nearest to united: nation, derision, legislature, konstantin, same, constitution, buckwheat, eurofighter,
# Nearest to of: including, pyroxene, in, justus, and, psionic, expiry, extremism,
# Nearest to by: through, inhalants, using, robins, without, millard, under, reestablishment,
# Nearest to zero: five, eight, seven, six, four, nine, three, kwh,
# Nearest to will: would, can, should, must, could, may, might, cannot,
# Nearest to system: systems, program, network, xenakis, enzyme, product, resolver, function,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 4 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 1 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  #tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 0.241283
# Nearest to who: projekt, processor, villas, troglodytes, lug, aliyah, fouls, colliery,
# Nearest to over: holliday, antebellum, wilkins, putting, clean, recognized, jiu, repairs,
# Nearest to known: salm, huns, shi, equivalence, acoustics, indeed, mather, cousins,
# Nearest to often: fernando, equilateral, amigas, holes, hitchcock, jeffreys, chords, butter,
# Nearest to on: evade, misleadingly, distributors, postmodernists, illuminate, zygote, sfor, warren,
# Nearest to while: romero, venture, fatwa, loran, iww, colchis, ether, germany,
# Nearest to called: argues, til, supplemental, auxiliaries, tuition, explorations, gondwana, dignities,
# Nearest to six: udma, dartmouth, kleine, belzec, completions, usurpers, sing, chef,
# Nearest to first: refugees, dismissal, avowed, korchnoi, priest, lajos, strive, wilhelmshaven,
# Nearest to been: brainstem, withdrawals, shooters, almond, modestly, edwards, shortening, secretly,
# Nearest to two: theatrically, denigrating, housemates, algeciras, altering, economics, apiaceae, exposed,
# Nearest to were: composed, hedonism, schweitzer, belatedly, investiture, deacons, dystrophy, secreting,
# Nearest to seven: privations, secret, deploying, conservation, dmca, sons, ech, romance,
# Nearest to i: analytic, uganda, downgraded, ran, boo, buckley, asbury, spice,
# Nearest to have: area, barrister, marshalling, inversions, commentaries, expedition, framed, tomcats,
# Nearest to many: osmotic, yankee, route, deuterostomes, datum, condemn, proudest, grammar,
# Average loss at step 2000: 1.189931
# Average loss at step 4000: 1.005043
# Average loss at step 6000: 0.954804
# Average loss at step 8000: 0.907946
# Average loss at step 10000: 0.902024
# Nearest to who: villas, processor, projekt, angell, walsingham, colliery, totem, wavering,
# Nearest to over: holliday, insulinotherapy, bithynia, germanium, wilkins, antebellum, jiu, stumbled,
# Nearest to known: salm, yehoshua, implausible, huns, lesbian, acoustics, equivalence, cousins,
# Nearest to often: equilateral, chords, expositions, jeffreys, allomorphy, berio, ichthyology, filenames,
# Nearest to on: heft, regional, brightness, probabilities, sfor, illuminate, torre, centromere,
# Nearest to while: romero, nation, iww, venture, slur, brontosaurus, likud, ether,
# Nearest to called: til, argues, supplemental, grampus, explorations, manaus, auxiliaries, walsingham,
# Nearest to six: nine, career, kleine, udma, one, manicheanism, eight, ollie,
# Nearest to first: dismissal, avowed, strive, stories, keir, calculates, arithmetica, became,
# Nearest to been: brainstem, shortening, withdrawals, fabulous, boudicca, shooters, gritty, wankel,
# Nearest to two: zero, one, four, five, three, boilers, january, brawl,
# Nearest to were: composed, maffei, deacons, lily, reciprocate, forall, secreting, transpose,
# Nearest to seven: inroads, privations, tegucigalpa, obelix, clashes, two, lighters, despise,
# Nearest to i: defenders, excision, uganda, brigade, ethic, lingua, consecrated, do,
# Nearest to have: hadley, barrister, inflammation, nanometer, precludes, enniskillen, inversions, tomcats,
# Nearest to many: route, osmotic, yankee, jerome, grammar, godlike, narnia, proudest,
# Average loss at step 12000: 0.873251
# Average loss at step 14000: 0.804895
# Average loss at step 16000: 0.783057
# Average loss at step 18000: 0.833059
# Average loss at step 20000: 0.828008
# Nearest to who: projekt, wainwright, dreary, nonnegative, villas, neocortex, colliery, furthered,
# Nearest to over: germanium, holliday, jiu, clean, ballad, insulinotherapy, putting, cliff,
# Nearest to known: yehoshua, salm, huns, lesbian, implausible, shi, equivalence, deceased,
# Nearest to often: chords, equilateral, ichthyology, disabled, berio, expositions, dispersed, pursuing,
# Nearest to on: cathode, blacki, berlusconi, catalonia, cords, biddle, credibility, perception,
# Nearest to while: romero, brontosaurus, iww, racks, valerie, layton, matchup, venture,
# Nearest to called: argues, grampus, til, supplemental, taxicab, manaus, gendered, explorations,
# Nearest to six: eight, five, two, four, three, one, nine, gladiatorial,
# Nearest to first: strive, avowed, lightning, unwelcome, priest, stories, ensemble, dismissal,
# Nearest to been: brainstem, reproducing, shortening, shooters, unlimited, whisky, recombine, bannockburn,
# Nearest to two: zero, five, one, three, four, eight, seven, six,
# Nearest to were: transpose, taylor, lily, hardliners, reciprocate, pickwick, maffei, forall,
# Nearest to seven: four, one, eight, five, nine, two, three, zero,
# Nearest to i: hilaire, faroes, ethic, casualties, garand, impeded, ran, defenders,
# Nearest to have: are, hadley, heidi, pea, precludes, ipx, barrister, llc,
# Nearest to many: grammar, narnia, abstractions, bled, vi, jerome, hural, durand,
# Average loss at step 22000: 0.836476
# Average loss at step 24000: 0.826604
# Average loss at step 26000: 0.772992
# Average loss at step 28000: 0.831509
# Average loss at step 30000: 0.814762
# Nearest to who: projekt, dreary, thereto, concede, omnia, flame, castilla, purporting,
# Nearest to over: germanium, sync, saloon, revolver, amu, jiu, putting, flea,
# Nearest to known: implausible, courtesy, yehoshua, lesbian, shi, huns, equivalence, dormitory,
# Nearest to often: ichthyology, disabled, offend, chords, equilateral, dispersed, circumstantial, berio,
# Nearest to on: at, noticing, infiltrate, kid, spectators, ditto, amalgam, endorsement,
# Nearest to while: romero, brontosaurus, impotent, dtmf, racks, reformist, iww, matchup,
# Nearest to called: argues, gendered, grampus, anisotropies, supplemental, til, novelties, kristin,
# Nearest to six: four, eight, two, five, three, one, nine, zero,
# Nearest to first: unwelcome, became, strive, coed, charenton, mensa, malwa, gnome,
# Nearest to been: brainstem, reproducing, shortening, primordial, strain, europa, coincidental, mikoto,
# Nearest to two: zero, five, four, six, three, one, eight, seven,
# Nearest to were: embarrassment, assessments, taylor, composed, praia, briggs, warfield, grasso,
# Nearest to seven: one, four, nine, eight, five, six, three, monogamy,
# Nearest to i: faroes, hilaire, penning, casualties, synthesizers, t, conservatively, garand,
# Nearest to have: taping, captaincy, verbose, hadley, mgh, ipx, poor, pea,
# Nearest to many: grammar, redeemer, marrakech, abstractions, godwin, country, stopping, feyerabend,
# Average loss at step 32000: 0.814737
# Average loss at step 34000: 0.775878
# Average loss at step 36000: 0.806390
# Average loss at step 38000: 0.783681
# Average loss at step 40000: 0.793805
# Nearest to who: projekt, purporting, omnia, shipyard, troubadour, hangover, diversifying, macrostate,
# Nearest to over: saloon, germanium, jiu, flea, dromedary, confederates, sabre, styled,
# Nearest to known: shi, courtesy, embrace, equivalence, translate, schoolboy, yehoshua, pbk,
# Nearest to often: ichthyology, offend, disabled, chorus, undecidable, circumstantial, butter, londinium,
# Nearest to on: canetti, potential, beings, saws, curled, prim, tractor, haag,
# Nearest to while: romero, insurgencies, abbreviated, tankers, matchup, loran, brontosaurus, backward,
# Nearest to called: gendered, supplemental, grampus, motherhood, discarding, animalium, acidic, argues,
# Nearest to six: eight, five, seven, nine, four, three, one, two,
# Nearest to first: became, shaffer, deuce, caledonia, climatology, unwelcome, dhimma, attachments,
# Nearest to been: reproducing, brainstem, injection, europa, erected, chlorine, obligate, mekong,
# Nearest to two: zero, one, five, three, eight, seven, four, nine,
# Nearest to were: are, sterling, embarrassment, wall, extensionality, tending, assessments, confused,
# Nearest to seven: one, four, eight, five, three, two, zero, nine,
# Nearest to i: t, fontane, conservatively, impeded, playstation, gather, faroes, hilaire,
# Nearest to have: hadley, has, be, motivate, acquainted, responding, piast, defeats,
# Nearest to many: most, abstractions, grammar, vannevar, some, invitational, feyerabend, mayotte,
# Average loss at step 42000: 0.791006
# Average loss at step 44000: 0.748392
# Average loss at step 46000: 0.756338
# Average loss at step 48000: 0.787798
# Average loss at step 50000: 0.776038
# Nearest to who: upstate, projekt, beaton, artisan, narrates, purporting, auratus, macedonia,
# Nearest to over: blah, saloon, amu, dromedary, sorts, stardust, abauzit, georges,
# Nearest to known: embrace, shi, courtesy, scottsdale, discoid, equivalence, translate, raft,
# Nearest to often: undecidable, butter, londinium, circumstantial, offend, chilled, chorus, ventura,
# Nearest to on: precious, from, attila, opposes, minotaurs, canetti, bnetd, ishaq,
# Nearest to while: romero, dtmf, matchup, insurgencies, substitute, maccabeus, groundwater, racks,
# Nearest to called: gendered, anisotropies, internally, interfering, grampus, relaxed, confessing, argues,
# Nearest to six: eight, five, four, nine, zero, two, seven, three,
# Nearest to first: unwelcome, courtroom, astbury, krieg, bestiary, lufthansa, kul, anteaters,
# Nearest to been: brainstem, seafaring, finalist, shortening, has, derided, fontsize, primordial,
# Nearest to two: zero, three, four, six, five, one, eight, sontag,
# Nearest to were: are, nietzsche, had, mycenae, gain, eminem, mosque, embarrassment,
# Nearest to seven: four, eight, one, six, nine, three, zero, five,
# Nearest to i: t, impeded, ethic, playstation, polyglot, separatism, promiscuity, fontane,
# Nearest to have: has, had, foresaw, are, hadley, be, choose, cereal,
# Nearest to many: most, some, feyerabend, godwin, corroborate, provisioning, origin, abstractions,
# Average loss at step 52000: 0.772123
# Average loss at step 54000: 0.777622
# Average loss at step 56000: 0.764636
# Average loss at step 58000: 0.723650
# Average loss at step 60000: 0.778963
# Nearest to who: purporting, upstate, anscombe, lawsuit, phyllis, systematized, homologous, cluniac,
# Nearest to over: saloon, dromedary, storks, exposure, emissary, dominos, confederates, canaan,
# Nearest to known: jurists, sus, syracuse, huns, vater, cartography, dormitory, pbk,
# Nearest to often: chorus, offend, processor, bundle, pursuing, othon, zodiac, running,
# Nearest to on: fingers, svenska, reunite, monazite, palliative, chromite, dislodge, skins,
# Nearest to while: racks, romero, breatharian, substitute, with, bona, worldly, hiding,
# Nearest to called: internally, remonstrance, alf, southward, argues, adrian, eduard, object,
# Nearest to six: seven, zero, four, five, eight, two, three, nine,
# Nearest to first: russians, cascade, loos, mia, astbury, samir, soaps, advances,
# Nearest to been: has, primordial, finalist, voss, derided, clair, some, fontsize,
# Nearest to two: zero, five, four, three, six, seven, eight, one,
# Nearest to were: are, was, awkward, hessian, distinction, wedlock, cuauht, operetta,
# Nearest to seven: six, eight, nine, four, five, zero, three, one,
# Nearest to i: t, paradox, impeded, liqueur, nutation, clairvoyance, fundraiser, kellogg,
# Nearest to have: has, defeats, canard, had, enniskillen, are, kazimierz, some,
# Nearest to many: other, some, jama, most, circle, principal, sibelius, faq,
# Average loss at step 62000: 0.761740
# Average loss at step 64000: 0.757120
# Average loss at step 66000: 0.764428
# Average loss at step 68000: 0.751677
# Average loss at step 70000: 0.740355
# Nearest to who: navarre, he, concede, astrophysicist, witness, smells, homologous, parthian,
# Nearest to over: saloon, amu, perkins, otto, interbreed, about, fanpage, azt,
# Nearest to known: dormitory, yehoshua, ecoregions, vater, rgensen, huns, jurists, scottsdale,
# Nearest to often: ichi, zodiac, automobile, running, theseus, calories, ir, offend,
# Nearest to on: akihito, grossing, from, contemplating, euphemism, fucked, cass, decca,
# Nearest to while: romero, racks, bona, tetrahedra, substitute, matchup, crucial, brontosaurus,
# Nearest to called: internally, malleus, relaxed, southward, vie, clav, fatalities, remonstrance,
# Nearest to six: three, five, four, seven, two, zero, eight, one,
# Nearest to first: russians, advances, unimportant, soaps, evidenced, wool, curtain, romanian,
# Nearest to been: had, primordial, failing, that, has, voss, derided, clair,
# Nearest to two: zero, three, five, six, four, eight, one, seven,
# Nearest to were: are, was, dbv, undifferentiated, had, circumstance, subatomic, hey,
# Nearest to seven: six, five, eight, nine, four, three, one, two,
# Nearest to i: t, m, abstractions, quantum, impeded, classicism, bronchitis, paradox,
# Nearest to have: deals, are, had, enjoy, has, loaf, northumbria, supersymmetric,
# Nearest to many: other, nihilism, corroborate, marca, members, jama, some, cassatt,
# Average loss at step 72000: 0.746109
# Average loss at step 74000: 0.754994
# Average loss at step 76000: 0.743636
# Average loss at step 78000: 0.751599
# Average loss at step 80000: 0.734381
# Nearest to who: macmullen, foretold, wombat, expropriated, instructive, spaceship, marduk, navarre,
# Nearest to over: azt, saloon, exposure, mondo, embodied, gentis, ku, headquartered,
# Nearest to known: well, dormitory, ecoregions, yehoshua, scottsdale, treated, vater, syracuse,
# Nearest to often: processor, theseus, caledonian, zodiac, doubts, ichi, disabled, navies,
# Nearest to on: attentive, illuminate, materiality, fatwas, sichuan, cheers, curled, canadians,
# Nearest to while: contrasting, ferdinando, dani, thus, hydrophilic, bona, liszt, voris,
# Nearest to called: cheltenham, internally, malleus, vie, object, bagapsh, relaxed, function,
# Nearest to six: five, four, seven, three, eight, nine, zero, two,
# Nearest to first: voters, unsuspecting, russians, adolphe, highlighting, romanian, unregulated, plundering,
# Nearest to been: had, primordial, has, fortran, was, seafaring, elevated, have,
# Nearest to two: four, three, zero, one, eight, five, six, journalist,
# Nearest to were: are, factories, was, had, headline, deciphered, don, marta,
# Nearest to seven: six, five, nine, three, eight, one, four, two,
# Nearest to i: t, what, supervising, quantum, my, faroes, promiscuity, absinthe,
# Nearest to have: has, had, been, be, but, mailbox, saginaw, superheroic,
# Nearest to many: jama, most, kindred, other, aids, strangled, members, against,
# Average loss at step 82000: 0.753087
# Average loss at step 84000: 0.761199
# Average loss at step 86000: 0.725762
# Average loss at step 88000: 0.734927
# Average loss at step 90000: 0.703738
# Nearest to who: jabberwocky, wheaton, preventive, offense, macmullen, bending, protocol, jetty,
# Nearest to over: saloon, azt, gentis, exposure, storks, fingers, rob, enzyme,
# Nearest to known: well, acetyl, called, vater, outrageous, sarabande, ecoregions, as,
# Nearest to often: lukoff, ichi, theseus, rc, used, plugins, whitacre, caledonian,
# Nearest to on: bacilli, unintentional, diverted, postmodernists, subclasses, americanized, at, albania,
# Nearest to while: contrasting, bolstering, stance, inquisitions, older, dizziness, sectarian, subsistence,
# Nearest to called: internally, participating, known, malleus, cheltenham, xnor, sensors, haphazard,
# Nearest to six: one, four, five, seven, eight, three, two, zero,
# Nearest to first: plundering, oneida, stephanie, ominous, fontaine, framers, tomatoes, calendar,
# Nearest to been: absentee, primordial, obligate, circumscription, has, convenient, injection, were,
# Nearest to two: zero, five, one, three, four, eight, seven, six,
# Nearest to were: are, had, effect, been, centred, unsympathetic, jung, joined,
# Nearest to seven: eight, nine, three, five, one, six, four, zero,
# Nearest to i: t, d, supervising, e, h, my, naaman, mares,
# Nearest to have: hamster, had, has, be, twain, so, shafts, schuster,
# Nearest to many: most, other, brienne, revivals, bismuth, demographic, mancala, ifs,
# Average loss at step 92000: 0.740680
# Average loss at step 94000: 0.720134
# Average loss at step 96000: 0.738015
# Average loss at step 98000: 0.743685
# Average loss at step 100000: 0.737195
# Nearest to who: goon, underlined, cede, cambrian, upstate, cluniac, foretold, jabberwocky,
# Nearest to over: saloon, headquartered, rob, exposure, stardust, antwerp, adrien, sync,
# Nearest to known: well, also, killer, acetyl, called, riesz, sarabande, huns,
# Nearest to often: ichi, offer, homologous, conifer, alfaro, septicemic, notebooks, shaping,
# Nearest to on: kama, very, azeglio, matilda, at, gilchrist, normal, karpov,
# Nearest to while: assay, contrasting, sectarian, inquisitions, stance, foresaw, tm, routine,
# Nearest to called: internally, known, sulfates, xnor, malleus, cheltenham, bullets, dorsal,
# Nearest to six: five, seven, three, zero, eight, four, two, one,
# Nearest to first: ominous, fontaine, mahoney, aran, meet, constructive, duality, gay,
# Nearest to been: has, primordial, krona, convenient, have, had, lesbian, would,
# Nearest to two: zero, seven, one, five, three, six, four, eight,
# Nearest to were: are, speciality, had, cassatt, stapleton, papers, dostoevsky, unsympathetic,
# Nearest to seven: eight, five, four, two, six, three, zero, nine,
# Nearest to i: t, d, e, my, m, vulva, h, supervising,
# Nearest to have: has, apiaceae, had, so, are, been, precludes, vaughn,
# Nearest to many: other, different, particular, cassation, relatedness, including, several, some,
